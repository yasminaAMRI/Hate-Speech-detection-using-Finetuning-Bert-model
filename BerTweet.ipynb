# %% [markdown]
# <center><h1 style="color:red">Hate Speech Detection in Tweets and Explanation Using LLMs</h1></center>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import necessary libraries

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 7.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 18.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install emoji==0.6.0
# Out:
# Collecting emoji==0.6.0
#   Downloading emoji-0.6.0.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-0.6.0-py3-none-any.whl size=49719 sha256=a9741b6d7d506d002b3704d1e8beba7fb72d507d356f9f1452ea380d86340d46
#   Stored in directory: /root/.cache/pip/wheels/1b/bd/d9/310c33c45a553798a714e27e3b8395d37128425442b8c78e07
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-0.6.0

# %%
import pandas as pd
import numpy as np
import re
import string
import unicodedata
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, pipeline
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report, confusion_matrix
import shap
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # 1. Data Preparation

# %% [markdown]
# ### Load the labeled tweet dataset

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/train.csv")

# Afficher les premières lignes pour vérifier l'ensemble de données
print("Dataset loaded successfully.")
print(data.head())
# Out:
# Dataset loaded successfully.
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %% [markdown]
# ###  Preprocess the tweets

# %%
# Initialiser les stopwords anglais et ajouter des stopwords personnalisés
stop_english = set(stopwords.words('english'))
custom_stopwords = set(["u", "ur", "im", "dont", "cant", "wont", "didnt", "couldnt", "youre"])
stop_english.update(custom_stopwords)

def clean_tweet(tweet):

    tweet = re.sub(r"http\S+|www\S+", '', tweet)  # Supprimer les URLs
    tweet = re.sub(r"@\w+", '', tweet)  # Supprimer les mentions
    tweet = re.sub(r"#(\w+)", r"\1", tweet)  # Gérer les hashtags
    tweet = re.sub(r"[^\w\s]", '', tweet)  # Supprimer la ponctuation
    tweet = ' '.join([word for word in tweet.split() if word not in stop_english]) # Suprrimer stopwords

    return tweet

# Nettoyer les tweets
data['tweet'] = data['tweet'].apply(clean_tweet)

# %% [markdown]
# ### Remove Duplicate Tweets

# %%
# Supprimer les lignes dupliquées en fonction des tweets nettoyés
data = data.drop_duplicates(subset='tweet', keep='first')

# Vérifiez la taille du jeu de données mis à jour
print(f"Dataset size after removing duplicates: {data.shape[0]} rows")
# Out:
# Dataset size after removing duplicates: 28456 rows

# %% [markdown]
# ### Handle Class Imbalance

# %%
# Séparer les données en classes majoritaire et minoritaire
not_hate = data[data['label'] == 0]
hate = data[data['label'] == 1]

# Réaliser l'undersampling de la classe majoritaire
not_hate_downsampled = resample(not_hate, replace=False, n_samples=hate.shape[0], random_state=42)

# Combiner les deux classes pour former le dataset équilibré
new_data = pd.concat([not_hate_downsampled, hate])

# Mélanger les données
new_data = new_data.sample(frac=1, random_state=42).reset_index(drop=True)

# Afficher la taille des classes après équilibrage
print("Taille des classes après undersampling :")
print(new_data['label'].value_counts())

print('la taille de data après undersampling :\n ', new_data.shape)

# Enregistrer le dataframe équilibré sous forme de fichier CSV
new_data.to_csv('/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/new_data.csv', index=False)
# Out:
# Taille des classes après undersampling :
# label
# 0    1865
# 1    1865
# Name: count, dtype: int64
# la taille de data après undersampling :
#   (3730, 3)

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/new_data.csv")

# %% [markdown]
# # 2. Fine-tuning a Pre-Trained Model

# %% [markdown]
# ### Load tokenizer and model

# %%
tokenizer = AutoTokenizer.from_pretrained('vinai/bertweet-base')
model = AutoModelForSequenceClassification.from_pretrained('vinai/bertweet-base', num_labels=2)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/558 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/843k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.91M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/543M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/bertweet-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Split the Dataset

# %%
# Diviser le data en Train (80%) et test (20%)
data_train, data_test = train_test_split(data, test_size=0.2, random_state=42, stratify=data['label'])

# Diviser train en train et validation
data_train, data_val = train_test_split(data_train, test_size=0.1, random_state=42, stratify=data_train['label'])

# Vérifier la répartition des ensembles
print(f"Train set size: {data_train.shape[0]} rows")
print(f"Validation set size: {data_val.shape[0]} rows")
print(f"Test set size: {data_test.shape[0]} rows")
# Out:
# Train set size: 2685 rows
# Validation set size: 299 rows
# Test set size: 746 rows

# %% [markdown]
# ### Convert data to Hugging Face's Dataset format

# %%
def convert_to_hf_dataset(data):
    return Dataset.from_pandas(data[['tweet', 'label']])

train_dataset = convert_to_hf_dataset(data_train)
val_dataset = convert_to_hf_dataset(data_val)
test_dataset = convert_to_hf_dataset(data_test)

# %% [markdown]
# ### Tokenize the dataset

# %%
def tokenize_function(examples):
    return tokenizer(examples['tweet'], truncation=True, padding='max_length', max_length=128)

train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

train_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
val_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
# Out:
# Map:   0%|          | 0/2685 [00:00<?, ? examples/s]
# Map:   0%|          | 0/299 [00:00<?, ? examples/s]
# Map:   0%|          | 0/746 [00:00<?, ? examples/s]

# %% [markdown]
# ### Define training arguments

# %%
training_args = TrainingArguments(
    output_dir='/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/results',
    eval_strategy='epoch',
    save_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/logs',
    logging_steps=10,
)

# %% [markdown]
# ### Define metrics

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = np.argmax(pred.predictions, axis=1)

    # Calculer les métriques pour chaque classe (0 et 1)
    precision, recall, f1, support = precision_recall_fscore_support(labels, preds, labels=[0, 1])

    # Calculer la précision, le rappel et le f1-score pour chaque classe
    precision_0, precision_1 = precision
    recall_0, recall_1 = recall
    f1_0, f1_1 = f1
    support_0, support_1 = support

    # Calculer l'accuracy globale
    acc = accuracy_score(labels, preds)

    return {
        'accuracy': acc,
        'precision_class_0': precision_0,
        'precision_class_1': precision_1,
        'recall_class_0': recall_0,
        'recall_class_1': recall_1,
        'f1_class_0': f1_0,
        'f1_class_1': f1_1,
        'support_class_0': support_0,
        'support_class_1': support_1
    }

# %% [markdown]
# ### Create Trainer

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# <ipython-input-16-ebd1ae3858e0>:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %% [markdown]
# ### Train and save the model

# %%
# Train the model
trainer.train()

# Save the model
model_path = '/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/BerTweet_trained_model'
tokenizer_path = '/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/BerTweet_trained_tokenizer'

model.save_pretrained(model_path)
tokenizer.save_pretrained(tokenizer_path)

print("Model and tokenizer saved successfully.")
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20241225_000702-v5jhrvza</code>
# Syncing run <strong><a href='https://wandb.ai/yasminaamri-universit-mohamed-premier-oujda/huggingface/runs/v5jhrvza' target="_blank">/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/results</a></strong> to <a href='https://wandb.ai/yasminaamri-universit-mohamed-premier-oujda/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yasminaamri-universit-mohamed-premier-oujda/huggingface' target="_blank">https://wandb.ai/yasminaamri-universit-mohamed-premier-oujda/huggingface</a>
#  View run at <a href='https://wandb.ai/yasminaamri-universit-mohamed-premier-oujda/huggingface/runs/v5jhrvza' target="_blank">https://wandb.ai/yasminaamri-universit-mohamed-premier-oujda/huggingface/runs/v5jhrvza</a>
#     <div>
#
#       <progress value='504' max='504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [504/504 3:26:30, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision Class 0</th>
#       <th>Precision Class 1</th>
#       <th>Recall Class 0</th>
#       <th>Recall Class 1</th>
#       <th>F1 Class 0</th>
#       <th>F1 Class 1</th>
#       <th>Support Class 0</th>
#       <th>Support Class 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.313600</td>
#       <td>0.304455</td>
#       <td>0.882943</td>
#       <td>0.896552</td>
#       <td>0.870130</td>
#       <td>0.866667</td>
#       <td>0.899329</td>
#       <td>0.881356</td>
#       <td>0.884488</td>
#       <td>150</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.315600</td>
#       <td>0.285289</td>
#       <td>0.886288</td>
#       <td>0.975410</td>
#       <td>0.824859</td>
#       <td>0.793333</td>
#       <td>0.979866</td>
#       <td>0.875000</td>
#       <td>0.895706</td>
#       <td>150</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.138600</td>
#       <td>0.253678</td>
#       <td>0.903010</td>
#       <td>0.935252</td>
#       <td>0.875000</td>
#       <td>0.866667</td>
#       <td>0.939597</td>
#       <td>0.899654</td>
#       <td>0.906149</td>
#       <td>150</td>
#       <td>149</td>
#     </tr>
#   </tbody>
# </table><p>
# Model and tokenizer saved successfully.

# %% [markdown]
# # 3. Explainability with SHAP

# %% [markdown]
# #### 3.1.Reload the trained model and tokenizer

# %%
model_path = '/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/BerTweet_trained_model'
tokenizer_path = '/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/BerTweet_trained_tokenizer'

# Charger le modèle
model = AutoModelForSequenceClassification.from_pretrained(model_path)

# Charger le tokenizer
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)

# Créer un pipeline pour la classification
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)
# Out:
# Device set to use cpu

# %% [markdown]
# #### 3.2.Préparer les données

# %%
# Sélectionner quelques exemples du jeu de données de test pour l'explicabilité
sample_data = data_test.sample(n=10, random_state=1)

# Extraire les tweets et les labels
tweets_test = sample_data['tweet'].tolist()
labels_test = sample_data['label'].tolist()

print('Exemple de jeu de données de test :\n',sample_data.head())
# Out:
# Exemple de jeu de données de test :
#           id  label                                              tweet
# 3288  17345      0                         know account hacked ok bye
# 3624  20291      0  babies officially seniors heavyhea letsummerbegin
# 2412   2930      1  democrat pay alway pay black inferior whites w...
# 734    5957      0  feeling close people orlando today prayers cas...
# 2173   2383      0                                         makes svsu

# %% [markdown]
# #### 3.3.Utiliser SHAP pour l'explication

# %%
# Créer un explainer SHAP pour le pipeline de classification
explainer = shap.Explainer(classifier)

# Calculer les valeurs SHAP pour les tweets d'exemple
shap_values = explainer(tweets_test)

# Afficher les explications pour un tweet spécifique
shap.plots.text(shap_values[0], display=True)
# Out:
# PartitionExplainer explainer:  10%|█         | 1/10 [00:00<?, ?it/s]
#   0%|          | 0/90 [00:00<?, ?it/s]
# PartitionExplainer explainer:  30%|███       | 3/10 [00:29<00:35,  5.09s/it]
#   0%|          | 0/132 [00:00<?, ?it/s]
# PartitionExplainer explainer:  40%|████      | 4/10 [00:42<00:50,  8.40s/it]
#   0%|          | 0/110 [00:00<?, ?it/s]
# PartitionExplainer explainer:  60%|██████    | 6/10 [00:55<00:26,  6.73s/it]
#   0%|          | 0/156 [00:00<?, ?it/s]
# PartitionExplainer explainer:  70%|███████   | 7/10 [01:11<00:30, 10.03s/it]
#   0%|          | 0/342 [00:00<?, ?it/s]
# PartitionExplainer explainer:  80%|████████  | 8/10 [01:57<00:42, 21.42s/it]
#   0%|          | 0/210 [00:00<?, ?it/s]
# PartitionExplainer explainer:  90%|█████████ | 9/10 [02:20<00:22, 22.04s/it]
#   0%|          | 0/132 [00:00<?, ?it/s]
# PartitionExplainer explainer: 100%|██████████| 10/10 [02:35<00:00, 19.96s/it]
#   0%|          | 0/132 [00:00<?, ?it/s]
# PartitionExplainer explainer: 11it [02:50, 17.00s/it]
# <div align='center'>
# <script>
#     document._hover_ahftrxckafnafqofpvau = '_tp_ahftrxckafnafqofpvau_output_0';
#     document._zoom_ahftrxckafnafqofpvau = undefined;
#     function _output_onclick_ahftrxckafnafqofpvau(i) {
#         var next_id = undefined;
#
#         if (document._zoom_ahftrxckafnafqofpvau !== undefined) {
#             document.getElementById(document._zoom_ahftrxckafnafqofpvau+ '_zoom').style.display = 'none';
#
#             if (document._zoom_ahftrxckafnafqofpvau === '_tp_ahftrxckafnafqofpvau_output_' + i) {
#                 document.getElementById(document._zoom_ahftrxckafnafqofpvau).style.display = 'block';
#                 document.getElementById(document._zoom_ahftrxckafnafqofpvau+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_ahftrxckafnafqofpvau).style.display = 'none';
#                 document.getElementById(document._zoom_ahftrxckafnafqofpvau+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_ahftrxckafnafqofpvau !== '_tp_ahftrxckafnafqofpvau_output_' + i) {
#             next_id = '_tp_ahftrxckafnafqofpvau_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_ahftrxckafnafqofpvau = next_id;
#     }
#     function _output_onmouseover_ahftrxckafnafqofpvau(i, el) {
#         if (document._zoom_ahftrxckafnafqofpvau !== undefined) { return; }
#         if (document._hover_ahftrxckafnafqofpvau !== undefined) {
#             document.getElementById(document._hover_ahftrxckafnafqofpvau + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_ahftrxckafnafqofpvau).style.display = 'none';
#         }
#         document.getElementById('_tp_ahftrxckafnafqofpvau_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_ahftrxckafnafqofpvau = '_tp_ahftrxckafnafqofpvau_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_ahftrxckafnafqofpvau_output_0_name"
#     onclick="_output_onclick_ahftrxckafnafqofpvau(0)"
#     onmouseover="_output_onmouseover_ahftrxckafnafqofpvau(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_ahftrxckafnafqofpvau_output_1_name"
#     onclick="_output_onclick_ahftrxckafnafqofpvau(1)"
#     onmouseover="_output_onmouseover_ahftrxckafnafqofpvau(1, this);">LABEL_1</div><br><br><div id='_tp_ahftrxckafnafqofpvau_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.315786040146826%" y1="33" x2="50.315786040146826%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.315786040146826%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.79502750611574%" y1="33" x2="36.79502750611574%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.79502750611574%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="23.27426897208465%" y1="33" x2="23.27426897208465%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="23.27426897208465%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="9.753510438053553%" y1="33" x2="9.753510438053553%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="9.753510438053553%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="63.836544574177914%" y1="33" x2="63.836544574177914%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.836544574177914%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="77.35730310820901%" y1="33" x2="77.35730310820901%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.35730310820901%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="90.8780616422401%" y1="33" x2="90.8780616422401%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.8780616422401%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="79.70189430559012%" y1="33" x2="79.70189430559012%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.70189430559012%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.934681</text><text x="79.70189430559012%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.934681</text><text x="79.70189430559012%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="59.53364214247625%" y1="33" x2="59.53364214247625%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.53364214247625%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.636351</text><text x="59.53364214247625%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.636351</text><text x="59.53364214247625%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="44.29924230742578%" width="15.234399835050473%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="46.00703106183857%" x2="59.53364214247625%" y1="60" y2="60" id="_fb_sieyiccwpusnzjovqwps_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="52.770336602157414%" y="71" font-size="12px" id="_fs_sieyiccwpusnzjovqwps_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.2</text><svg x="46.00703106183857%" y="40" height="20" width="13.526611080637686%">  <svg x="0" y="0" width="100%" height="100%">    <text x ...

# %%
shap.plots.text(shap_values[0], display=True)
# Out:
# <div align='center'>
# <script>
#     document._hover_srngqcllywgnexwhqpdt = '_tp_srngqcllywgnexwhqpdt_output_0';
#     document._zoom_srngqcllywgnexwhqpdt = undefined;
#     function _output_onclick_srngqcllywgnexwhqpdt(i) {
#         var next_id = undefined;
#
#         if (document._zoom_srngqcllywgnexwhqpdt !== undefined) {
#             document.getElementById(document._zoom_srngqcllywgnexwhqpdt+ '_zoom').style.display = 'none';
#
#             if (document._zoom_srngqcllywgnexwhqpdt === '_tp_srngqcllywgnexwhqpdt_output_' + i) {
#                 document.getElementById(document._zoom_srngqcllywgnexwhqpdt).style.display = 'block';
#                 document.getElementById(document._zoom_srngqcllywgnexwhqpdt+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_srngqcllywgnexwhqpdt).style.display = 'none';
#                 document.getElementById(document._zoom_srngqcllywgnexwhqpdt+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_srngqcllywgnexwhqpdt !== '_tp_srngqcllywgnexwhqpdt_output_' + i) {
#             next_id = '_tp_srngqcllywgnexwhqpdt_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_srngqcllywgnexwhqpdt = next_id;
#     }
#     function _output_onmouseover_srngqcllywgnexwhqpdt(i, el) {
#         if (document._zoom_srngqcllywgnexwhqpdt !== undefined) { return; }
#         if (document._hover_srngqcllywgnexwhqpdt !== undefined) {
#             document.getElementById(document._hover_srngqcllywgnexwhqpdt + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_srngqcllywgnexwhqpdt).style.display = 'none';
#         }
#         document.getElementById('_tp_srngqcllywgnexwhqpdt_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_srngqcllywgnexwhqpdt = '_tp_srngqcllywgnexwhqpdt_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_srngqcllywgnexwhqpdt_output_0_name"
#     onclick="_output_onclick_srngqcllywgnexwhqpdt(0)"
#     onmouseover="_output_onmouseover_srngqcllywgnexwhqpdt(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_srngqcllywgnexwhqpdt_output_1_name"
#     onclick="_output_onclick_srngqcllywgnexwhqpdt(1)"
#     onmouseover="_output_onmouseover_srngqcllywgnexwhqpdt(1, this);">LABEL_1</div><br><br><div id='_tp_srngqcllywgnexwhqpdt_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.315786040146826%" y1="33" x2="50.315786040146826%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.315786040146826%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.79502750611574%" y1="33" x2="36.79502750611574%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.79502750611574%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="23.27426897208465%" y1="33" x2="23.27426897208465%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="23.27426897208465%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="9.753510438053553%" y1="33" x2="9.753510438053553%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="9.753510438053553%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="63.836544574177914%" y1="33" x2="63.836544574177914%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.836544574177914%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="77.35730310820901%" y1="33" x2="77.35730310820901%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.35730310820901%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="90.8780616422401%" y1="33" x2="90.8780616422401%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.8780616422401%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="79.70189430559012%" y1="33" x2="79.70189430559012%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.70189430559012%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.934681</text><text x="79.70189430559012%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.934681</text><text x="79.70189430559012%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="59.53364214247625%" y1="33" x2="59.53364214247625%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.53364214247625%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.636351</text><text x="59.53364214247625%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.636351</text><text x="59.53364214247625%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="44.29924230742578%" width="15.234399835050473%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="46.00703106183857%" x2="59.53364214247625%" y1="60" y2="60" id="_fb_ounaiaywvhbwycmbttdm_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="52.770336602157414%" y="71" font-size="12px" id="_fs_ounaiaywvhbwycmbttdm_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.2</text><svg x="46.00703106183857%" y="40" height="20" width="13.526611080637686%">  <svg x="0" y="0" width="100%" height="100%">    <text x ...

# %%
shap.plots.text(shap_values[1], display=True)
# Out:
# <div align='center'>
# <script>
#     document._hover_ywemfkbjzgulkyzosehz = '_tp_ywemfkbjzgulkyzosehz_output_0';
#     document._zoom_ywemfkbjzgulkyzosehz = undefined;
#     function _output_onclick_ywemfkbjzgulkyzosehz(i) {
#         var next_id = undefined;
#
#         if (document._zoom_ywemfkbjzgulkyzosehz !== undefined) {
#             document.getElementById(document._zoom_ywemfkbjzgulkyzosehz+ '_zoom').style.display = 'none';
#
#             if (document._zoom_ywemfkbjzgulkyzosehz === '_tp_ywemfkbjzgulkyzosehz_output_' + i) {
#                 document.getElementById(document._zoom_ywemfkbjzgulkyzosehz).style.display = 'block';
#                 document.getElementById(document._zoom_ywemfkbjzgulkyzosehz+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_ywemfkbjzgulkyzosehz).style.display = 'none';
#                 document.getElementById(document._zoom_ywemfkbjzgulkyzosehz+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_ywemfkbjzgulkyzosehz !== '_tp_ywemfkbjzgulkyzosehz_output_' + i) {
#             next_id = '_tp_ywemfkbjzgulkyzosehz_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_ywemfkbjzgulkyzosehz = next_id;
#     }
#     function _output_onmouseover_ywemfkbjzgulkyzosehz(i, el) {
#         if (document._zoom_ywemfkbjzgulkyzosehz !== undefined) { return; }
#         if (document._hover_ywemfkbjzgulkyzosehz !== undefined) {
#             document.getElementById(document._hover_ywemfkbjzgulkyzosehz + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_ywemfkbjzgulkyzosehz).style.display = 'none';
#         }
#         document.getElementById('_tp_ywemfkbjzgulkyzosehz_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_ywemfkbjzgulkyzosehz = '_tp_ywemfkbjzgulkyzosehz_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_ywemfkbjzgulkyzosehz_output_0_name"
#     onclick="_output_onclick_ywemfkbjzgulkyzosehz(0)"
#     onmouseover="_output_onmouseover_ywemfkbjzgulkyzosehz(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_ywemfkbjzgulkyzosehz_output_1_name"
#     onclick="_output_onclick_ywemfkbjzgulkyzosehz(1)"
#     onmouseover="_output_onmouseover_ywemfkbjzgulkyzosehz(1, this);">LABEL_1</div><br><br><div id='_tp_ywemfkbjzgulkyzosehz_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.43732326994883%" y1="33" x2="50.43732326994883%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.43732326994883%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.573412267355835%" y1="33" x2="34.573412267355835%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.573412267355835%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="18.709501264762846%" y1="33" x2="18.709501264762846%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.709501264762846%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="66.3012342725418%" y1="33" x2="66.3012342725418%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.3012342725418%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="82.16514527513482%" y1="33" x2="82.16514527513482%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="82.16514527513482%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="56.97122511766805%" y1="33" x2="56.97122511766805%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="56.97122511766805%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.623562</text><text x="56.97122511766805%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.623562</text><text x="56.97122511766805%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="74.8973398326721%" y1="33" x2="74.8973398326721%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="74.8973398326721%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.96256</text><text x="74.8973398326721%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.96256</text><text x="74.8973398326721%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="37.546184978476%" width="37.35115485419611%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="58.21446445636098%" x2="74.8973398326721%" y1="60" y2="60" id="_fb_potbpnweyceprgdxgpqk_ind_8" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="66.55590214451654%" y="71" font-size="12px" id="_fs_potbpnweyceprgdxgpqk_ind_8" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.315</text><svg x="58.21446445636098%" y="40" height="20" width="16.682875376311124%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">begin</text>  </svg></svg><line x1="47.804078671671775%" x2="58.21446445636098%" y1="60" y2="60" id="_fb_potbpnweyceprgdxgpqk_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="53.00927156401637%" y="71" font-size="12px" id="_fs_potbpnweyceprgdxgpqk_ind_7" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.197</ ...

# %%
# explain the predictions of the pipeline on the first two samples
explainer = shap.Explainer(classifier)  # Your pipeline
shap_values = explainer(tweets_test[:8])
# Out:
#   0%|          | 0/90 [00:00<?, ?it/s]
# PartitionExplainer explainer:  25%|██▌       | 2/8 [00:00<?, ?it/s]
#   0%|          | 0/132 [00:00<?, ?it/s]
# PartitionExplainer explainer:  50%|█████     | 4/8 [00:26<00:26,  6.57s/it]
#   0%|          | 0/110 [00:00<?, ?it/s]
# PartitionExplainer explainer:  75%|███████▌  | 6/8 [00:38<00:12,  6.03s/it]
#   0%|          | 0/156 [00:00<?, ?it/s]
# PartitionExplainer explainer:  88%|████████▊ | 7/8 [00:55<00:09,  9.68s/it]
#   0%|          | 0/342 [00:00<?, ?it/s]
# PartitionExplainer explainer: 100%|██████████| 8/8 [01:40<00:00, 21.60s/it]
#   0%|          | 0/210 [00:00<?, ?it/s]
# PartitionExplainer explainer: 9it [02:04, 17.73s/it]

# %%
# Loop through the first 8 samples
for i in range(8):
    # Display the SHAP explanation for the current sample
    shap.plots.text(shap_values[i], display=True)
# Out:
# <div align='center'>
# <script>
#     document._hover_ovpddixuwxfgcuwkqeyw = '_tp_ovpddixuwxfgcuwkqeyw_output_0';
#     document._zoom_ovpddixuwxfgcuwkqeyw = undefined;
#     function _output_onclick_ovpddixuwxfgcuwkqeyw(i) {
#         var next_id = undefined;
#
#         if (document._zoom_ovpddixuwxfgcuwkqeyw !== undefined) {
#             document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw+ '_zoom').style.display = 'none';
#
#             if (document._zoom_ovpddixuwxfgcuwkqeyw === '_tp_ovpddixuwxfgcuwkqeyw_output_' + i) {
#                 document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw).style.display = 'block';
#                 document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw).style.display = 'none';
#                 document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_ovpddixuwxfgcuwkqeyw !== '_tp_ovpddixuwxfgcuwkqeyw_output_' + i) {
#             next_id = '_tp_ovpddixuwxfgcuwkqeyw_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_ovpddixuwxfgcuwkqeyw = next_id;
#     }
#     function _output_onmouseover_ovpddixuwxfgcuwkqeyw(i, el) {
#         if (document._zoom_ovpddixuwxfgcuwkqeyw !== undefined) { return; }
#         if (document._hover_ovpddixuwxfgcuwkqeyw !== undefined) {
#             document.getElementById(document._hover_ovpddixuwxfgcuwkqeyw + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_ovpddixuwxfgcuwkqeyw).style.display = 'none';
#         }
#         document.getElementById('_tp_ovpddixuwxfgcuwkqeyw_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_ovpddixuwxfgcuwkqeyw = '_tp_ovpddixuwxfgcuwkqeyw_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_ovpddixuwxfgcuwkqeyw_output_0_name"
#     onclick="_output_onclick_ovpddixuwxfgcuwkqeyw(0)"
#     onmouseover="_output_onmouseover_ovpddixuwxfgcuwkqeyw(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_ovpddixuwxfgcuwkqeyw_output_1_name"
#     onclick="_output_onclick_ovpddixuwxfgcuwkqeyw(1)"
#     onmouseover="_output_onmouseover_ovpddixuwxfgcuwkqeyw(1, this);">LABEL_1</div><br><br><div id='_tp_ovpddixuwxfgcuwkqeyw_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.315786040146826%" y1="33" x2="50.315786040146826%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.315786040146826%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.79502750611574%" y1="33" x2="36.79502750611574%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.79502750611574%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="23.27426897208465%" y1="33" x2="23.27426897208465%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="23.27426897208465%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="9.753510438053553%" y1="33" x2="9.753510438053553%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="9.753510438053553%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="63.836544574177914%" y1="33" x2="63.836544574177914%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.836544574177914%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="77.35730310820901%" y1="33" x2="77.35730310820901%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.35730310820901%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="90.8780616422401%" y1="33" x2="90.8780616422401%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.8780616422401%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="79.70189430559012%" y1="33" x2="79.70189430559012%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.70189430559012%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.934681</text><text x="79.70189430559012%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.934681</text><text x="79.70189430559012%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="59.53364214247625%" y1="33" x2="59.53364214247625%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="59.53364214247625%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.636351</text><text x="59.53364214247625%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.636351</text><text x="59.53364214247625%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="44.29924230742578%" width="15.234399835050473%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="46.00703106183857%" x2="59.53364214247625%" y1="60" y2="60" id="_fb_zvwatiyuwvgucwwfvlhu_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="52.770336602157414%" y="71" font-size="12px" id="_fs_zvwatiyuwvgucwwfvlhu_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.2</text><svg x="46.00703106183857%" y="40" height="20" width="13.526611080637686%">  <svg x="0" y="0" width="100%" height="100%">    <text x ...
# <div align='center'>
# <script>
#     document._hover_fmxuecnqivtrffagmwbk = '_tp_fmxuecnqivtrffagmwbk_output_0';
#     document._zoom_fmxuecnqivtrffagmwbk = undefined;
#     function _output_onclick_fmxuecnqivtrffagmwbk(i) {
#         var next_id = undefined;
#
#         if (document._zoom_fmxuecnqivtrffagmwbk !== undefined) {
#             document.getElementById(document._zoom_fmxuecnqivtrffagmwbk+ '_zoom').style.display = 'none';
#
#             if (document._zoom_fmxuecnqivtrffagmwbk === '_tp_fmxuecnqivtrffagmwbk_output_' + i) {
#                 document.getElementById(document._zoom_fmxuecnqivtrffagmwbk).style.display = 'block';
#                 document.getElementById(document._zoom_fmxuecnqivtrffagmwbk+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_fmxuecnqivtrffagmwbk).style.display = 'none';
#                 document.getElementById(document._zoom_fmxuecnqivtrffagmwbk+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_fmxuecnqivtrffagmwbk !== '_tp_fmxuecnqivtrffagmwbk_output_' + i) {
#             next_id = '_tp_fmxuecnqivtrffagmwbk_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_fmxuecnqivtrffagmwbk = next_id;
#     }
#     function _output_onmouseover_fmxuecnqivtrffagmwbk(i, el) {
#         if (document._zoom_fmxuecnqivtrffagmwbk !== undefined) { return; }
#         if (document._hover_fmxuecnqivtrffagmwbk !== undefined) {
#             document.getElementById(document._hover_fmxuecnqivtrffagmwbk + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_fmxuecnqivtrffagmwbk).style.display = 'none';
#         }
#         document.getElementById('_tp_fmxuecnqivtrffagmwbk_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_fmxuecnqivtrffagmwbk = '_tp_fmxuecnqivtrffagmwbk_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_fmxuecnqivtrffagmwbk_output_0_name"
#     onclick="_output_onclick_fmxuecnqivtrffagmwbk(0)"
#     onmouseover="_output_onmouseover_fmxuecnqivtrffagmwbk(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_fmxuecnqivtrffagmwbk_output_1_name"
#     onclick="_output_onclick_fmxuecnqivtrffagmwbk(1)"
#     onmouseover="_output_onmouseover_fmxuecnqivtrffagmwbk(1, this);">LABEL_1</div><br><br><div id='_tp_fmxuecnqivtrffagmwbk_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.43732326994883%" y1="33" x2="50.43732326994883%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.43732326994883%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.573412267355835%" y1="33" x2="34.573412267355835%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.573412267355835%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="18.709501264762846%" y1="33" x2="18.709501264762846%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.709501264762846%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="66.3012342725418%" y1="33" x2="66.3012342725418%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.3012342725418%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="82.16514527513482%" y1="33" x2="82.16514527513482%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="82.16514527513482%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="56.97122511766805%" y1="33" x2="56.97122511766805%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="56.97122511766805%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.623562</text><text x="56.97122511766805%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.623562</text><text x="56.97122511766805%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="74.8973398326721%" y1="33" x2="74.8973398326721%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="74.8973398326721%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.96256</text><text x="74.8973398326721%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.96256</text><text x="74.8973398326721%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="37.546184978476%" width="37.35115485419611%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="58.21446445636098%" x2="74.8973398326721%" y1="60" y2="60" id="_fb_qfsmgratucleynbgwlur_ind_8" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="66.55590214451654%" y="71" font-size="12px" id="_fs_qfsmgratucleynbgwlur_ind_8" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.315</text><svg x="58.21446445636098%" y="40" height="20" width="16.682875376311124%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">begin</text>  </svg></svg><line x1="47.804078671671775%" x2="58.21446445636098%" y1="60" y2="60" id="_fb_qfsmgratucleynbgwlur_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="53.00927156401637%" y="71" font-size="12px" id="_fs_qfsmgratucleynbgwlur_ind_7" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.197</ ...
# <div align='center'>
# <script>
#     document._hover_akoaqdmbjfitjtvgcaoz = '_tp_akoaqdmbjfitjtvgcaoz_output_0';
#     document._zoom_akoaqdmbjfitjtvgcaoz = undefined;
#     function _output_onclick_akoaqdmbjfitjtvgcaoz(i) {
#         var next_id = undefined;
#
#         if (document._zoom_akoaqdmbjfitjtvgcaoz !== undefined) {
#             document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz+ '_zoom').style.display = 'none';
#
#             if (document._zoom_akoaqdmbjfitjtvgcaoz === '_tp_akoaqdmbjfitjtvgcaoz_output_' + i) {
#                 document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz).style.display = 'block';
#                 document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz).style.display = 'none';
#                 document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_akoaqdmbjfitjtvgcaoz !== '_tp_akoaqdmbjfitjtvgcaoz_output_' + i) {
#             next_id = '_tp_akoaqdmbjfitjtvgcaoz_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_akoaqdmbjfitjtvgcaoz = next_id;
#     }
#     function _output_onmouseover_akoaqdmbjfitjtvgcaoz(i, el) {
#         if (document._zoom_akoaqdmbjfitjtvgcaoz !== undefined) { return; }
#         if (document._hover_akoaqdmbjfitjtvgcaoz !== undefined) {
#             document.getElementById(document._hover_akoaqdmbjfitjtvgcaoz + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_akoaqdmbjfitjtvgcaoz).style.display = 'none';
#         }
#         document.getElementById('_tp_akoaqdmbjfitjtvgcaoz_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_akoaqdmbjfitjtvgcaoz = '_tp_akoaqdmbjfitjtvgcaoz_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_akoaqdmbjfitjtvgcaoz_output_0_name"
#     onclick="_output_onclick_akoaqdmbjfitjtvgcaoz(0)"
#     onmouseover="_output_onmouseover_akoaqdmbjfitjtvgcaoz(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_akoaqdmbjfitjtvgcaoz_output_1_name"
#     onclick="_output_onclick_akoaqdmbjfitjtvgcaoz(1)"
#     onmouseover="_output_onmouseover_akoaqdmbjfitjtvgcaoz(1, this);">LABEL_1</div><br><br><div id='_tp_akoaqdmbjfitjtvgcaoz_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="48.581439760827024%" y1="33" x2="48.581439760827024%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="48.581439760827024%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="33.372640856916725%" y1="33" x2="33.372640856916725%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.372640856916725%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="18.163841953006433%" y1="33" x2="18.163841953006433%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.163841953006433%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="63.79023866473731%" y1="33" x2="63.79023866473731%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.79023866473731%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="78.99903756864761%" y1="33" x2="78.99903756864761%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="78.99903756864761%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="57.047916900858695%" y1="33" x2="57.047916900858695%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="57.047916900858695%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.511337</text><text x="57.047916900858695%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.511337</text><text x="57.047916900858695%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="18.163841953006433%" y1="33" x2="18.163841953006433%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.163841953006433%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="18.163841953006433%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="18.163841953006433%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="6.267646571155429%" width="11.896195381851006%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="9.778999213324244%" x2="18.163841953006433%" y1="60" y2="60" id="_fb_jquqtyfaddrofsteptcv_ind_10" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="13.971420583165338%" y="71" font-size="12px" id="_fs_jquqtyfaddrofsteptcv_ind_10" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.11</text><svg x="9.778999213324244%" y="40" height="20" width="8.384842739682188%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">everybody</text>  </svg></svg><line x1="6.997344449155825%" x2="9.778999213324244%" y1="60" y2="60" id="_fb_jquqtyfaddrofsteptcv_ind_3" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="8.388171831240035%" y="71" font-size="12px" id="_fs_jquqtyfaddrofsteptcv_ind_3" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor=" ...
# <div align='center'>
# <script>
#     document._hover_smtrqmucfrhpmnltishg = '_tp_smtrqmucfrhpmnltishg_output_0';
#     document._zoom_smtrqmucfrhpmnltishg = undefined;
#     function _output_onclick_smtrqmucfrhpmnltishg(i) {
#         var next_id = undefined;
#
#         if (document._zoom_smtrqmucfrhpmnltishg !== undefined) {
#             document.getElementById(document._zoom_smtrqmucfrhpmnltishg+ '_zoom').style.display = 'none';
#
#             if (document._zoom_smtrqmucfrhpmnltishg === '_tp_smtrqmucfrhpmnltishg_output_' + i) {
#                 document.getElementById(document._zoom_smtrqmucfrhpmnltishg).style.display = 'block';
#                 document.getElementById(document._zoom_smtrqmucfrhpmnltishg+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_smtrqmucfrhpmnltishg).style.display = 'none';
#                 document.getElementById(document._zoom_smtrqmucfrhpmnltishg+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_smtrqmucfrhpmnltishg !== '_tp_smtrqmucfrhpmnltishg_output_' + i) {
#             next_id = '_tp_smtrqmucfrhpmnltishg_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_smtrqmucfrhpmnltishg = next_id;
#     }
#     function _output_onmouseover_smtrqmucfrhpmnltishg(i, el) {
#         if (document._zoom_smtrqmucfrhpmnltishg !== undefined) { return; }
#         if (document._hover_smtrqmucfrhpmnltishg !== undefined) {
#             document.getElementById(document._hover_smtrqmucfrhpmnltishg + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_smtrqmucfrhpmnltishg).style.display = 'none';
#         }
#         document.getElementById('_tp_smtrqmucfrhpmnltishg_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_smtrqmucfrhpmnltishg = '_tp_smtrqmucfrhpmnltishg_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_smtrqmucfrhpmnltishg_output_0_name"
#     onclick="_output_onclick_smtrqmucfrhpmnltishg(0)"
#     onmouseover="_output_onmouseover_smtrqmucfrhpmnltishg(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_smtrqmucfrhpmnltishg_output_1_name"
#     onclick="_output_onclick_smtrqmucfrhpmnltishg(1)"
#     onmouseover="_output_onmouseover_smtrqmucfrhpmnltishg(1, this);">LABEL_1</div><br><br><div id='_tp_smtrqmucfrhpmnltishg_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="48.86926244066236%" y1="33" x2="48.86926244066236%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="48.86926244066236%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="39.095409952529884%" y1="33" x2="39.095409952529884%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.095409952529884%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="29.321557464397415%" y1="33" x2="29.321557464397415%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.321557464397415%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="19.54770497626494%" y1="33" x2="19.54770497626494%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="19.54770497626494%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="9.77385248813247%" y1="33" x2="9.77385248813247%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="9.77385248813247%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="58.64311492879483%" y1="33" x2="58.64311492879483%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.64311492879483%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="68.4169674169273%" y1="33" x2="68.4169674169273%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.4169674169273%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="78.19081990505977%" y1="33" x2="78.19081990505977%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="78.19081990505977%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="87.96467239319225%" y1="33" x2="87.96467239319225%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="87.96467239319225%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="50.1422878613917%" y1="33" x2="50.1422878613917%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.1422878613917%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.513025</text><text x="50.1422878613917%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.513025</text><text x="50.1422878613917%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="95.30870198316171%" y1="33" x2="95.30870198316171%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="95.30870198316171%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.97514</text><text x="95.30870198316171%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.97514</text><text x="95.30870198316171%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="49.99674150532832%" width="45.31196047783338%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="83.76618538697159%" ...
# <div align='center'>
# <script>
#     document._hover_xvbehtohdrsynmcbligc = '_tp_xvbehtohdrsynmcbligc_output_0';
#     document._zoom_xvbehtohdrsynmcbligc = undefined;
#     function _output_onclick_xvbehtohdrsynmcbligc(i) {
#         var next_id = undefined;
#
#         if (document._zoom_xvbehtohdrsynmcbligc !== undefined) {
#             document.getElementById(document._zoom_xvbehtohdrsynmcbligc+ '_zoom').style.display = 'none';
#
#             if (document._zoom_xvbehtohdrsynmcbligc === '_tp_xvbehtohdrsynmcbligc_output_' + i) {
#                 document.getElementById(document._zoom_xvbehtohdrsynmcbligc).style.display = 'block';
#                 document.getElementById(document._zoom_xvbehtohdrsynmcbligc+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_xvbehtohdrsynmcbligc).style.display = 'none';
#                 document.getElementById(document._zoom_xvbehtohdrsynmcbligc+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_xvbehtohdrsynmcbligc !== '_tp_xvbehtohdrsynmcbligc_output_' + i) {
#             next_id = '_tp_xvbehtohdrsynmcbligc_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_xvbehtohdrsynmcbligc = next_id;
#     }
#     function _output_onmouseover_xvbehtohdrsynmcbligc(i, el) {
#         if (document._zoom_xvbehtohdrsynmcbligc !== undefined) { return; }
#         if (document._hover_xvbehtohdrsynmcbligc !== undefined) {
#             document.getElementById(document._hover_xvbehtohdrsynmcbligc + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_xvbehtohdrsynmcbligc).style.display = 'none';
#         }
#         document.getElementById('_tp_xvbehtohdrsynmcbligc_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_xvbehtohdrsynmcbligc = '_tp_xvbehtohdrsynmcbligc_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_xvbehtohdrsynmcbligc_output_0_name"
#     onclick="_output_onclick_xvbehtohdrsynmcbligc(0)"
#     onmouseover="_output_onmouseover_xvbehtohdrsynmcbligc(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_xvbehtohdrsynmcbligc_output_1_name"
#     onclick="_output_onclick_xvbehtohdrsynmcbligc(1)"
#     onmouseover="_output_onmouseover_xvbehtohdrsynmcbligc(1, this);">LABEL_1</div><br><br><div id='_tp_xvbehtohdrsynmcbligc_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.042283594068586%" y1="33" x2="47.042283594068586%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.042283594068586%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="30.886306917190236%" y1="33" x2="30.886306917190236%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="30.886306917190236%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="14.730330240311895%" y1="33" x2="14.730330240311895%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.730330240311895%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="63.19826027094692%" y1="33" x2="63.19826027094692%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.19826027094692%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="79.35423694782526%" y1="33" x2="79.35423694782526%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.35423694782526%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="92.24821110566579%" y1="33" x2="92.24821110566579%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="92.24821110566579%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.959619</text><text x="92.24821110566579%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.959619</text><text x="92.24821110566579%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="14.730330240311895%" y1="33" x2="14.730330240311895%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.730330240311895%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="14.730330240311895%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="14.730330240311895%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="14.730330240311895%" width="0.0%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="translate(-8,0)" x="14.730330240311895%" y="40" width="8" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792)"/><g transform="translate(-11.5,0)">  <svg x="14.730330240311895%" y="40" height="18" overflow="visible" width="30">    <path d="M 10 -9 l 6 18 L 10 25 L 0 25 L 0 -9" fill="#ffffff" style="stroke:rgb(255,255,255);stroke-width:2" />  </svg></g><rect x="14.730330240311895%" width="77.5178808653539%" y="40" height="18" style="fill:rgb(0.0, 138.56128015770727, 250.76166088685727); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="14.730330240311895%" x2="42.15923501230289%" y1="60" y2="60" id="_fb_zvoyzrhbtmqxepqmcjir_ind_4" style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2; opacity: 0"/><text x="28.44478262630739%" y="71" font-size="12px" fill="rgb(0.0, 138.56128015770727, 250.76166088685727)" id="_fs_zvoyzrhbtmqxepqmcjir_ind_4" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">-0.34</text><svg x="14.730330240311895%" y="40" height="20" width="27.428904771990993%">  < ...
# <div align='center'>
# <script>
#     document._hover_hpzmdoiooliesogubtsv = '_tp_hpzmdoiooliesogubtsv_output_0';
#     document._zoom_hpzmdoiooliesogubtsv = undefined;
#     function _output_onclick_hpzmdoiooliesogubtsv(i) {
#         var next_id = undefined;
#
#         if (document._zoom_hpzmdoiooliesogubtsv !== undefined) {
#             document.getElementById(document._zoom_hpzmdoiooliesogubtsv+ '_zoom').style.display = 'none';
#
#             if (document._zoom_hpzmdoiooliesogubtsv === '_tp_hpzmdoiooliesogubtsv_output_' + i) {
#                 document.getElementById(document._zoom_hpzmdoiooliesogubtsv).style.display = 'block';
#                 document.getElementById(document._zoom_hpzmdoiooliesogubtsv+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_hpzmdoiooliesogubtsv).style.display = 'none';
#                 document.getElementById(document._zoom_hpzmdoiooliesogubtsv+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_hpzmdoiooliesogubtsv !== '_tp_hpzmdoiooliesogubtsv_output_' + i) {
#             next_id = '_tp_hpzmdoiooliesogubtsv_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_hpzmdoiooliesogubtsv = next_id;
#     }
#     function _output_onmouseover_hpzmdoiooliesogubtsv(i, el) {
#         if (document._zoom_hpzmdoiooliesogubtsv !== undefined) { return; }
#         if (document._hover_hpzmdoiooliesogubtsv !== undefined) {
#             document.getElementById(document._hover_hpzmdoiooliesogubtsv + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_hpzmdoiooliesogubtsv).style.display = 'none';
#         }
#         document.getElementById('_tp_hpzmdoiooliesogubtsv_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_hpzmdoiooliesogubtsv = '_tp_hpzmdoiooliesogubtsv_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_hpzmdoiooliesogubtsv_output_0_name"
#     onclick="_output_onclick_hpzmdoiooliesogubtsv(0)"
#     onmouseover="_output_onmouseover_hpzmdoiooliesogubtsv(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_hpzmdoiooliesogubtsv_output_1_name"
#     onclick="_output_onclick_hpzmdoiooliesogubtsv(1)"
#     onmouseover="_output_onmouseover_hpzmdoiooliesogubtsv(1, this);">LABEL_1</div><br><br><div id='_tp_hpzmdoiooliesogubtsv_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.47681440938445%" y1="33" x2="49.47681440938445%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.47681440938445%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.230323465850304%" y1="33" x2="34.230323465850304%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.230323465850304%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="18.983832522316156%" y1="33" x2="18.983832522316156%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.983832522316156%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.3</text><line x1="64.7233053529186%" y1="33" x2="64.7233053529186%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="64.7233053529186%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="79.96979629645273%" y1="33" x2="79.96979629645273%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.96979629645273%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.3</text><line x1="49.671278048690255%" y1="33" x2="49.671278048690255%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.671278048690255%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.505102</text><text x="49.671278048690255%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.505102</text><text x="49.671278048690255%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="67.33715066407721%" y1="33" x2="67.33715066407721%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="67.33715066407721%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.968576</text><text x="67.33715066407721%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.968576</text><text x="67.33715066407721%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="23.924393304338743%" width="43.41275735973847%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="55.07218770581602%" x2="67.33715066407721%" y1="60" y2="60" id="_fb_krvzmanpwwlnlskremzi_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="61.20466918494662%" y="71" font-size="12px" id="_fs_krvzmanpwwlnlskremzi_ind_7" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.322</text><svg x="55.07218770581602%" y="40" height="20" width="12.264962958261194%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">sday</text>  </svg></svg><line x1="43.29228807802877%" x2="55.07218770581602%" y1="60" y2="60" id="_fb_krvzmanpwwlnlskremzi_ind_11" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="49.1822378919224%" y="71" font-size="12px" id="_fs_krvzmanpwwlnlskremzi_ind_11" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor=" ...
# <div align='center'>
# <script>
#     document._hover_hzrhortbpmxhupjqqrsr = '_tp_hzrhortbpmxhupjqqrsr_output_0';
#     document._zoom_hzrhortbpmxhupjqqrsr = undefined;
#     function _output_onclick_hzrhortbpmxhupjqqrsr(i) {
#         var next_id = undefined;
#
#         if (document._zoom_hzrhortbpmxhupjqqrsr !== undefined) {
#             document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr+ '_zoom').style.display = 'none';
#
#             if (document._zoom_hzrhortbpmxhupjqqrsr === '_tp_hzrhortbpmxhupjqqrsr_output_' + i) {
#                 document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr).style.display = 'block';
#                 document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr).style.display = 'none';
#                 document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_hzrhortbpmxhupjqqrsr !== '_tp_hzrhortbpmxhupjqqrsr_output_' + i) {
#             next_id = '_tp_hzrhortbpmxhupjqqrsr_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_hzrhortbpmxhupjqqrsr = next_id;
#     }
#     function _output_onmouseover_hzrhortbpmxhupjqqrsr(i, el) {
#         if (document._zoom_hzrhortbpmxhupjqqrsr !== undefined) { return; }
#         if (document._hover_hzrhortbpmxhupjqqrsr !== undefined) {
#             document.getElementById(document._hover_hzrhortbpmxhupjqqrsr + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_hzrhortbpmxhupjqqrsr).style.display = 'none';
#         }
#         document.getElementById('_tp_hzrhortbpmxhupjqqrsr_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_hzrhortbpmxhupjqqrsr = '_tp_hzrhortbpmxhupjqqrsr_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_hzrhortbpmxhupjqqrsr_output_0_name"
#     onclick="_output_onclick_hzrhortbpmxhupjqqrsr(0)"
#     onmouseover="_output_onmouseover_hzrhortbpmxhupjqqrsr(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_hzrhortbpmxhupjqqrsr_output_1_name"
#     onclick="_output_onclick_hzrhortbpmxhupjqqrsr(1)"
#     onmouseover="_output_onmouseover_hzrhortbpmxhupjqqrsr(1, this);">LABEL_1</div><br><br><div id='_tp_hzrhortbpmxhupjqqrsr_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.12623937707704%" y1="33" x2="51.12623937707704%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.12623937707704%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.98768730413485%" y1="33" x2="34.98768730413485%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.98768730413485%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="18.84913523119266%" y1="33" x2="18.84913523119266%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.84913523119266%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="67.26479145001923%" y1="33" x2="67.26479145001923%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="67.26479145001923%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="83.40334352296142%" y1="33" x2="83.40334352296142%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.40334352296142%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="51.815002402794065%" y1="33" x2="51.815002402794065%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.815002402794065%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.508536</text><text x="51.815002402794065%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.508536</text><text x="51.815002402794065%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="10.779859194721562%" y1="33" x2="10.779859194721562%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="10.779859194721562%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="10.779859194721562%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="10.779859194721562%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="5.216238466459636%" width="5.5636207282619266%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.747784859995244%" x2="10.779859194721562%" y1="60" y2="60" id="_fb_vqxqilptchtedoznxvgv_ind_5" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="9.763822027358403%" y="71" font-size="12px" id="_fs_vqxqilptchtedoznxvgv_ind_5" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.025</text><svg x="8.747784859995244%" y="40" height="20" width="2.0320743347263175%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">ï</text>  </svg></svg><line x1="7.064317327351847%" x2="8.747784859995244%" y1="60" y2="60" id="_fb_vqxqilptchtedoznxvgv_ind_17" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="7.906051093673545%" y="71" font-size="12px" id="_fs_vqxqilptchtedoznxvgv_ind_17" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.021< ...
# <div align='center'>
# <script>
#     document._hover_rozjkedwlrqpaugdobtf = '_tp_rozjkedwlrqpaugdobtf_output_0';
#     document._zoom_rozjkedwlrqpaugdobtf = undefined;
#     function _output_onclick_rozjkedwlrqpaugdobtf(i) {
#         var next_id = undefined;
#
#         if (document._zoom_rozjkedwlrqpaugdobtf !== undefined) {
#             document.getElementById(document._zoom_rozjkedwlrqpaugdobtf+ '_zoom').style.display = 'none';
#
#             if (document._zoom_rozjkedwlrqpaugdobtf === '_tp_rozjkedwlrqpaugdobtf_output_' + i) {
#                 document.getElementById(document._zoom_rozjkedwlrqpaugdobtf).style.display = 'block';
#                 document.getElementById(document._zoom_rozjkedwlrqpaugdobtf+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_rozjkedwlrqpaugdobtf).style.display = 'none';
#                 document.getElementById(document._zoom_rozjkedwlrqpaugdobtf+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_rozjkedwlrqpaugdobtf !== '_tp_rozjkedwlrqpaugdobtf_output_' + i) {
#             next_id = '_tp_rozjkedwlrqpaugdobtf_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_rozjkedwlrqpaugdobtf = next_id;
#     }
#     function _output_onmouseover_rozjkedwlrqpaugdobtf(i, el) {
#         if (document._zoom_rozjkedwlrqpaugdobtf !== undefined) { return; }
#         if (document._hover_rozjkedwlrqpaugdobtf !== undefined) {
#             document.getElementById(document._hover_rozjkedwlrqpaugdobtf + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_rozjkedwlrqpaugdobtf).style.display = 'none';
#         }
#         document.getElementById('_tp_rozjkedwlrqpaugdobtf_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_rozjkedwlrqpaugdobtf = '_tp_rozjkedwlrqpaugdobtf_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_rozjkedwlrqpaugdobtf_output_0_name"
#     onclick="_output_onclick_rozjkedwlrqpaugdobtf(0)"
#     onmouseover="_output_onmouseover_rozjkedwlrqpaugdobtf(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_rozjkedwlrqpaugdobtf_output_1_name"
#     onclick="_output_onclick_rozjkedwlrqpaugdobtf(1)"
#     onmouseover="_output_onmouseover_rozjkedwlrqpaugdobtf(1, this);">LABEL_1</div><br><br><div id='_tp_rozjkedwlrqpaugdobtf_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.46415140559126%" y1="33" x2="51.46415140559126%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.46415140559126%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="35.95011251538163%" y1="33" x2="35.95011251538163%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="35.95011251538163%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="20.436073625172%" y1="33" x2="20.436073625172%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="20.436073625172%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.3</text><line x1="66.97819029580089%" y1="33" x2="66.97819029580089%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.97819029580089%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="82.49222918601052%" y1="33" x2="82.49222918601052%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="82.49222918601052%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.3</text><line x1="51.66601533162838%" y1="33" x2="51.66601533162838%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.66601533162838%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.505205</text><text x="51.66601533162838%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.505205</text><text x="51.66601533162838%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="32.071602792829225%" y1="33" x2="32.071602792829225%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="32.071602792829225%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="32.071602792829225%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="32.071602792829225%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="6.978134843704798%" width="25.093467949124424%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="22.52964388716774%" x2="32.071602792829225%" y1="60" y2="60" id="_fb_fwidxawddgeraaugiebt_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="27.30062333999848%" y="71" font-size="12px" id="_fs_fwidxawddgeraaugiebt_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.246</text><svg x="22.52964388716774%" y="40" height="20" width="9.541958905661485%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">moto</text>  </svg></svg><line x1="16.504087473892223%" x2="22.52964388716774%" y1="60" y2="60" id="_fb_fwidxawddgeraaugiebt_ind_6" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="19.516865680529982%" y="71" font-size="12px" id="_fs_fwidxawddgeraaugiebt_ind_6" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.155</text><s ...

# %% [markdown]
# # 4. Model Evaluation

# %%
# Recharger le modèle et le tokenizer
model = AutoModelForSequenceClassification.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)

# Créer un pipeline pour la classification
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Faire des prédictions sur l'ensemble de test
tweets_test = data_test['tweet'].tolist()
labels_test = data_test['label'].tolist()

# Prédire les labels
predictions = classifier(tweets_test)

# Extraire les labels prédits et les probabilités
predicted_labels = [pred['label'] for pred in predictions]
predicted_labels = [1 if label == 'LABEL_1' else 0 for label in predicted_labels]

# Afficher les métriques de classification
print("Classification Report:")
print(classification_report(labels_test, predicted_labels, target_names=['Non Hate Speech', 'Hate Speech']))

# Générer la matrice de confusion
conf_matrix = confusion_matrix(labels_test, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non Hate Speech', 'Hate Speech'],
            yticklabels=['Non Hate Speech', 'Hate Speech'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Device set to use cpu
# Classification Report:
#                  precision    recall  f1-score   support
#
# Non Hate Speech       0.92      0.83      0.87       373
#     Hate Speech       0.84      0.92      0.88       373
#
#        accuracy                           0.88       746
#       macro avg       0.88      0.88      0.88       746
#    weighted avg       0.88      0.88      0.88       746

# %% [markdown]
# # 5. Local Web-Based User Interface
